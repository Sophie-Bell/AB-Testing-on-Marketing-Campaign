# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pickle

# %%
with open("../data/interim/01_control_df_processed.pkl", "rb") as file:
    control_df = pickle.load(file)
    
with open("../data/interim/01_test_df_processed.pkl", "rb") as file:
    test_df = pickle.load(file)

# %%
def calculate_and_add_kpis(df):
    # Calculate Cost Per Click (CPC)
    df['CPC'] = df['Spend [USD]'] / df['# of Website Clicks']

    # Calculate Cost Per Acquisition (CPA)
    df['CPA'] = df['Spend [USD]'] / df['# of Purchase']

    # Calculate Average Order Value (AOV)
    df['AOV'] = df['Spend [USD]'] / df['# of Purchase']
    
    # Calculate CTR
    df['CTR'] = (df['# of Website Clicks'] / df['# of Impressions']) * 100
    
    # Calculate Conversion Rate
    df['Conversion Rate'] = (df['# of Purchase'] / df['# of Website Clicks']) * 100

    return df

# Call the function with your DataFrame
test_df = calculate_and_add_kpis(test_df)
control_df = calculate_and_add_kpis(control_df)

# %%
test_df.head(5)
# Out:
#    Campaign Name       Date  Spend [USD]  # of Impressions  Reach  \
# 0  Test Campaign 2019-08-01         3008             39550  35820
# 1  Test Campaign 2019-08-02         2542            100719  91236
# 2  Test Campaign 2019-08-03         2365             70263  45198
# 3  Test Campaign 2019-08-04         2710             78451  25937
# 4  Test Campaign 2019-08-05         2297            114295  95138
#
#    # of Website Clicks  # of Searches  # of View Content  # of Add to Cart  \
# 0                 3038           1946               1069               894
# 1                 4657           2359               1548               879
# 2                 7885           2572               2367              1268
# 3                 4216           2216               1437               566
# 4                 5863           2106                858               956
#
#    # of Purchase       CPC        CPA        AOV        CTR  Conversion Rate
# 0            255  0.990125  11.796078  11.796078   7.681416         8.393680
# 1            677  0.545845   3.754801   3.754801   4.623755        14.537256
# 2            578  0.299937   4.091696   4.091696  11.222123         7.330374
# 3            340  0.642789   7.970588   7.970588   5.374055         8.064516
# 4            768  0.391779   2.990885   2.990885   5.129708        13.099096

# %%
control_df.head(5)
# Out:
#       Campaign Name       Date  Spend [USD]  # of Impressions     Reach  \
# 0  Control Campaign 2019-08-01         2280           82702.0   56930.0
# 1  Control Campaign 2019-08-02         1757          121040.0  102513.0
# 2  Control Campaign 2019-08-03         2343          131711.0  110862.0
# 3  Control Campaign 2019-08-04         1940           72878.0   61235.0
# 5  Control Campaign 2019-08-06         3083          109076.0   87998.0
#
#    # of Website Clicks  # of Searches  # of View Content  # of Add to Cart  \
# 0               7016.0         2290.0             2159.0            1819.0
# 1               8110.0         2033.0             1841.0            1219.0
# 2               6508.0         1737.0             1549.0            1134.0
# 3               3065.0         1042.0              982.0            1183.0
# 5               4028.0         1709.0             1249.0             784.0
#
#    # of Purchase       CPC       CPA       AOV       CTR  Conversion Rate
# 0          618.0  0.324971  3.689320  3.689320  8.483471         8.808438
# 1          511.0  0.216646  3.438356  3.438356  6.700264         6.300863
# 2          372.0  0.360018  6.298387  6.298387  4.941121         5.716042
# 3          340.0  0.632953  5.705882  5.705882  4.205659        11.092985
# 5          764.0  0.765392  4.035340  4.035340  3.692838        18.967229

# %%
# upload to to processed
control_df.to_pickle("../data/processed/control_df_processed.pkl")
test_df.to_pickle("../data/processed/test_df_processed.pkl")
